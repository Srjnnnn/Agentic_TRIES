# %%
from transformers import load_tool, ReactCodeAgent, HfApiEngine

# Import tool from Hub
image_generation_tool = load_tool("m-ric/text-to-image", cache=False)

# Import tool from LangChain
from transformers.agents.search import DuckDuckGoSearchTool

search_tool = DuckDuckGoSearchTool()

llm_engine = HfApiEngine("Qwen/Qwen2.5-72B-Instruct")
# Initialize the agent with both tools
agent = ReactCodeAgent(tools=[search_tool], llm_engine=llm_engine)

# Run it!
result = agent.run(
    "What is PEFT? Can you explain to me and give me the resources you find?",
)
result
# Out:
# You're loading a tool from the Hub from None. Please make sure this is a source that you trust as the code within that tool will be executed on your machine. Always verify the code of the tools that you load. We recommend specifying a `revision` to ensure you're loading the code that you have checked.
# TextToImageTool implements a different description in its configuration and class. Using the tool configuration description.
# ======== New task ========
# What is PEFT? Can you explain to me and give me the resources you find?
# === Agent thoughts:
# Thought: I will use the tool `web_search` to find information about PEFT and provide relevant resources.
# >>> Agent is executing the code below:
# peft_info = web_search(query="What is PEFT")
# print(peft_info)
# ====
# Code execution failed due to the following error:
# _text_extract_json() keywords='What is PEFT' ValueError: subsection not found
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/utils.py", line 60, in _text_extract_json
#     end = html_bytes.index(b");DDG.duckbar.load(", start)
# ValueError: subsection not found
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1196, in step
#     result = self.python_evaluator(
#         code_action,
#     ...<3 lines>...
#         authorized_imports=self.authorized_imports,
#     )
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 902, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 439, in evaluate_call
#     output = func(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/tools.py", line 183, in __call__
#     outputs = self.forward(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/search.py", line 39, in forward
#     results = DDGS().text(query, max_results=7)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 243, in text
#     results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 330, in _text_api
#     raise e
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 327, in _text_api
#     for r in self._executor.map(_text_api_page, slist):
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ~~~~~~~~~~^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 306, in _text_api_page
#     page_data = _text_extract_json(resp_content, keywords)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/utils.py", line 65, in _text_extract_json
#     raise DuckDuckGoSearchException(f"_text_extract_json() {keywords=} {type(ex).__name__}: {ex}") from ex
# duckduckgo_search.exceptions.DuckDuckGoSearchException: _text_extract_json() keywords='What is PEFT' ValueError: subsection not found
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 856, in direct_run
#     self.step(step_log_entry)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1215, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# _text_extract_json() keywords='What is PEFT' ValueError: subsection not found
# === Agent thoughts:
# Thought: It seems there was an issue with the search query. I will refine the query and try again to find information about PEFT.
# >>> Agent is executing the code below:
# peft_info = web_search(query="PEFT definition and explanation")
# print(peft_info)
# ====
# Code execution failed due to the following error:
# https://links.duckduckgo.com/d.js?q=PEFT+definition+and+explanation&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-213989389877109926778876711019225944857&bing_market=wt-WT&ex=-1 202 Ratelimit
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1196, in step
#     result = self.python_evaluator(
#         code_action,
#     ...<3 lines>...
#         authorized_imports=self.authorized_imports,
#     )
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 902, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 439, in evaluate_call
#     output = func(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/tools.py", line 183, in __call__
#     outputs = self.forward(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/search.py", line 39, in forward
#     results = DDGS().text(query, max_results=7)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 243, in text
#     results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 330, in _text_api
#     raise e
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 327, in _text_api
#     for r in self._executor.map(_text_api_page, slist):
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ~~~~~~~~~~^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 305, in _text_api_page
#     resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 133, in _get_url
#     raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
# duckduckgo_search.exceptions.RatelimitException: https://links.duckduckgo.com/d.js?q=PEFT+definition+and+explanation&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-213989389877109926778876711019225944857&bing_market=wt-WT&ex=-1 202 Ratelimit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 856, in direct_run
#     self.step(step_log_entry)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1215, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# https://links.duckduckgo.com/d.js?q=PEFT+definition+and+explanation&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-213989389877109926778876711019225944857&bing_market=wt-WT&ex=-1 202 Ratelimit
# === Agent thoughts:
# Thought: It seems the web search is facing ratelimit issues. I will try a different approach by breaking down the search into more specific terms and using a direct query.
# >>> Agent is executing the code below:
# peft_info = web_search(query="PEFT in technology")
# print(peft_info)
# ====
# Code execution failed due to the following error:
# https://links.duckduckgo.com/d.js?q=PEFT+in+technology&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-55196130194510705307377007472254998514&bing_market=wt-WT&ex=-1 202 Ratelimit
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1196, in step
#     result = self.python_evaluator(
#         code_action,
#     ...<3 lines>...
#         authorized_imports=self.authorized_imports,
#     )
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 902, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 439, in evaluate_call
#     output = func(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/tools.py", line 183, in __call__
#     outputs = self.forward(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/search.py", line 39, in forward
#     results = DDGS().text(query, max_results=7)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 243, in text
#     results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 330, in _text_api
#     raise e
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 327, in _text_api
#     for r in self._executor.map(_text_api_page, slist):
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ~~~~~~~~~~^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 305, in _text_api_page
#     resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 133, in _get_url
#     raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
# duckduckgo_search.exceptions.RatelimitException: https://links.duckduckgo.com/d.js?q=PEFT+in+technology&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-55196130194510705307377007472254998514&bing_market=wt-WT&ex=-1 202 Ratelimit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 856, in direct_run
#     self.step(step_log_entry)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1215, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# https://links.duckduckgo.com/d.js?q=PEFT+in+technology&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-55196130194510705307377007472254998514&bing_market=wt-WT&ex=-1 202 Ratelimit
# === Agent thoughts:
# Thought: Given the ratelimit issues with the web search, I will attempt a different query and a different search engine.
# >>> Agent is executing the code below:
# peft_info = web_search(query="PEFT meaning")
# print(peft_info)
# ====
# Code execution failed due to the following error:
# https://links.duckduckgo.com/d.js?q=PEFT+meaning&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-13090427948707567856079562941087113289&bing_market=wt-WT&ex=-1 202 Ratelimit
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1196, in step
#     result = self.python_evaluator(
#         code_action,
#     ...<3 lines>...
#         authorized_imports=self.authorized_imports,
#     )
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 902, in evaluate_python_code
#     result = evaluate_ast(node, state, static_tools, custom_tools, authorized_imports)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 741, in evaluate_ast
#     return evaluate_assign(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 322, in evaluate_assign
#     result = evaluate_ast(assign.value, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 746, in evaluate_ast
#     return evaluate_call(expression, state, static_tools, custom_tools)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/python_interpreter.py", line 439, in evaluate_call
#     output = func(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/tools.py", line 183, in __call__
#     outputs = self.forward(*args, **kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/search.py", line 39, in forward
#     results = DDGS().text(query, max_results=7)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 243, in text
#     results = self._text_api(keywords, region, safesearch, timelimit, max_results)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 330, in _text_api
#     raise e
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 327, in _text_api
#     for r in self._executor.map(_text_api_page, slist):
#              ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 619, in result_iterator
#     yield _result_or_cancel(fs.pop())
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 317, in _result_or_cancel
#     return fut.result(timeout)
#            ~~~~~~~~~~^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 456, in result
#     return self.__get_result()
#            ~~~~~~~~~~~~~~~~~^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/_base.py", line 401, in __get_result
#     raise self._exception
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/concurrent/futures/thread.py", line 59, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 305, in _text_api_page
#     resp_content = self._get_url("GET", "https://links.duckduckgo.com/d.js", params=payload)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/duckduckgo_search/duckduckgo_search.py", line 133, in _get_url
#     raise RatelimitException(f"{resp.url} {resp.status_code} Ratelimit")
# duckduckgo_search.exceptions.RatelimitException: https://links.duckduckgo.com/d.js?q=PEFT+meaning&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-13090427948707567856079562941087113289&bing_market=wt-WT&ex=-1 202 Ratelimit
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 856, in direct_run
#     self.step(step_log_entry)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1215, in step
#     raise AgentExecutionError(error_msg)
# transformers.agents.agents.AgentExecutionError: Code execution failed due to the following error:
# https://links.duckduckgo.com/d.js?q=PEFT+meaning&kl=wt-wt&l=wt-wt&p=&s=0&df=&vqd=4-13090427948707567856079562941087113289&bing_market=wt-WT&ex=-1 202 Ratelimit
# Error in generating llm output: 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Qwen/Qwen2.5-72B-Instruct/v1/chat/completions (Request ID: ZvdURKTxjY1Afr5Ro9bxd)
#
# Model too busy, unable to get response in less than 60 second(s).
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/utils/_http.py", line 406, in hf_raise_for_status
#     response.raise_for_status()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/requests/models.py", line 1024, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Qwen/Qwen2.5-72B-Instruct/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1160, in step
#     llm_output = self.llm_engine(
#         self.prompt, stop_sequences=["<end_action>", "Observation:"], **additional_args
#     )
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/llm_engine.py", line 134, in __call__
#     response = self.generate(messages, stop_sequences, grammar)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/llm_engine.py", line 190, in generate
#     response = self.client.chat_completion(messages, stop=stop_sequences, max_tokens=self.max_tokens)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/inference/_client.py", line 892, in chat_completion
#     data = self.post(model=model_url, json=payload, stream=stream)
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/inference/_client.py", line 306, in post
#     hf_raise_for_status(response)
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/utils/_http.py", line 477, in hf_raise_for_status
#     raise _format(HfHubHTTPError, str(e), response) from e
# huggingface_hub.errors.HfHubHTTPError: 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Qwen/Qwen2.5-72B-Instruct/v1/chat/completions (Request ID: ZvdURKTxjY1Afr5Ro9bxd)
#
# Model too busy, unable to get response in less than 60 second(s)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 856, in direct_run
#     self.step(step_log_entry)
#     ~~~~~~~~~^^^^^^^^^^^^^^^^
#   File "/home/sercan/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py", line 1164, in step
#     raise AgentGenerationError(f"Error in generating llm output: {e}.")
# transformers.agents.agents.AgentGenerationError: Error in generating llm output: 500 Server Error: Internal Server Error for url: https://api-inference.huggingface.co/models/Qwen/Qwen2.5-72B-Instruct/v1/chat/completions (Request ID: ZvdURKTxjY1Afr5Ro9bxd)
#
# Model too busy, unable to get response in less than 60 second(s).
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 16
#      13 agent = ReactCodeAgent(tools=[search_tool], llm_engine=llm_engine)
#      15 # Run it!
# ---> 16 result = agent.run(
#      17     "What is PEFT? Can you explain to me and give me the resources you find?",
#      18 )
#      19 result
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py:802, in ReactAgent.run(self, task, stream, reset, **kwargs)
#     800     return self.stream_run(task)
#     801 else:
# --> 802     return self.direct_run(task)
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py:856, in ReactAgent.direct_run(self, task)
#     854 if self.planning_interval is not None and iteration % self.planning_interval == 0:
#     855     self.planning_step(task, is_first_step=(iteration == 0), iteration=iteration)
# --> 856 self.step(step_log_entry)
#     857 if "final_answer" in step_log_entry:
#     858     final_answer = step_log_entry["final_answer"]
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/agents.py:1160, in ReactCodeAgent.step(self, log_entry)
#    1158 try:
#    1159     additional_args = {"grammar": self.grammar} if self.grammar is not None else {}
# -> 1160     llm_output = self.llm_engine(
#    1161         self.prompt, stop_sequences=["<end_action>", "Observation:"], **additional_args
#    1162     )
#    1163 except Exception as e:
#    1164     raise AgentGenerationError(f"Error in generating llm output: {e}.")
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/llm_engine.py:134, in HfEngine.__call__(self, messages, stop_sequences, grammar)
#     132 if stop_sequences is None:
#     133     stop_sequences = []
# --> 134 response = self.generate(messages, stop_sequences, grammar)
#     135 self.last_input_token_count = len(self.tokenizer.apply_chat_template(messages, tokenize=True))
#     136 self.last_output_token_count = len(self.tokenizer.encode(response))
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/transformers/agents/llm_engine.py:190, in HfApiEngine.generate(self, messages, stop_sequences, grammar)
#     186     response = self.client.chat_completion(
#     187         messages, stop=stop_sequences, max_tokens=self.max_tokens, response_format=grammar
#     188     )
#     189 else:
# --> 190     response = self.client.chat_completion(messages, stop=stop_sequences, max_tokens=self.max_tokens)
#     192 response = response.choices[0].message.content
#     193 return response
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/inference/_client.py:892, in InferenceClient.chat_completion(self, messages, model, stream, frequency_penalty, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream_options, temperature, tool_choice, tool_prompt, tools, top_logprobs, top_p)
#     870 payload = dict(
#     871     model=model_id,
#     872     messages=messages,
#    (...)
#     889     stream_options=stream_options,
#     890 )
#     891 payload = {key: value for key, value in payload.items() if value is not None}
# --> 892 data = self.post(model=model_url, json=payload, stream=stream)
#     894 if stream:
#     895     return _stream_chat_completion_response(data)  # type: ignore[arg-type]
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/inference/_client.py:291, in InferenceClient.post(self, json, data, model, task, stream)
#     289 with _open_as_binary(data) as data_as_binary:
#     290     try:
# --> 291         response = get_session().post(
#     292             url,
#     293             json=json,
#     294             data=data_as_binary,
#     295             headers=headers,
#     296             cookies=self.cookies,
#     297             timeout=self.timeout,
#     298             stream=stream,
#     299             proxies=self.proxies,
#     300         )
#     301     except TimeoutError as error:
#     302         # Convert any `TimeoutError` to a `InferenceTimeoutError`
#     303         raise InferenceTimeoutError(f"Inference call timed out: {url}") from error  # type: ignore
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/requests/sessions.py:637, in Session.post(self, url, data, json, **kwargs)
#     626 def post(self, url, data=None, json=None, **kwargs):
#     627     r"""Sends a POST request. Returns :class:`Response` object.
#     628
#     629     :param url: URL for the new :class:`Request` object.
#    (...)
#     634     :rtype: requests.Response
#     635     """
# --> 637     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/huggingface_hub/utils/_http.py:93, in UniqueRequestIdAdapter.send(self, request, *args, **kwargs)
#      91 """Catch any RequestException to append request id to the error message for debugging."""
#      92 try:
# ---> 93     return super().send(request, *args, **kwargs)
#      94 except requests.RequestException as e:
#      95     request_id = request.headers.get(X_AMZN_TRACE_ID)
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/anaconda3/envs/general/lib/python3.13/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File ~/anaconda3/envs/general/lib/python3.13/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~/anaconda3/envs/general/lib/python3.13/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/anaconda3/envs/general/lib/python3.13/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/anaconda3/envs/general/lib/python3.13/socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~/anaconda3/envs/general/lib/python3.13/ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~/anaconda3/envs/general/lib/python3.13/ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
